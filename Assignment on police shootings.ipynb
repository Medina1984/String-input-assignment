# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Police_shootings = "https://raw.githubusercontent.com/Isinks/kadatemy-assignments/main/shootings.csv"
Police_shootings = pd.read_csv(Police_shootings)

# %%
Police_shootings.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# 0      M     Asian        Shelton    WA                     True       attack
# 1      M     White          Aloha    OR                    False       attack
# 2      M  Hispanic        Wichita    KS                    False        other
# 3      M     White  San Francisco    CA                     True       attack
# 4      M  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category
# ...

# %%
Police_shootings.tail()
# Out:
#         id             name        date manner_of_death    armed   age gender  \
# 4890  5916  Rayshard Brooks  2020-06-12            shot    Taser  27.0      M
# 4891  5925   Caine Van Pelt  2020-06-12            shot      gun  23.0      M
# 4892  5918     Hannah Fizer  2020-06-13            shot  unarmed  25.0      F
# 4893  5921   William Slyter  2020-06-13            shot      gun  22.0      M
# 4894  5924   Nicholas Hirsh  2020-06-15            shot      gun  31.0      M
#
#        race         city state  signs_of_mental_illness threat_level  \
# 4890  Black      Atlanta    GA                    False       attack
# 4891  Black  Crown Point    IN                    False       attack
# 4892  White      Sedalia    MO                    False        other
# 4893  White  Kansas City    MO                    False        other
# 4894  White     Lawrence    KS                    False       attack
#
#              flee  body_camera       arms_category
# ...

# %%
Police_shootings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
# ...

# %%
Police_shootings.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# arms_category              0
# dtype: int64

# %%
Police_shootings.describe(include="all")
# Out:
#                  id   name        date manner_of_death armed          age  \
# count   4895.000000   4895        4895            4895  4895  4895.000000
# unique          NaN   4851        1792               2    89          NaN
# top             NaN  TK TK  2018-01-06            shot   gun          NaN
# freq            NaN     29           9            4647  2755          NaN
# mean    2902.148519    NaN         NaN             NaN   NaN    36.549750
# std     1683.467910    NaN         NaN             NaN   NaN    12.694348
# min        3.000000    NaN         NaN             NaN   NaN     6.000000
# 25%     1441.500000    NaN         NaN             NaN   NaN    27.000000
# 50%     2847.000000    NaN         NaN             NaN   NaN    35.000000
# 75%     4352.500000    NaN         NaN             NaN   NaN    45.000000
# max     5925.000000    NaN         NaN             NaN   NaN    91.000000
#
#        gender   race         city state signs_of_mental_illness threat_level  \
# ...

# %% [markdown]
# From the dataset above, we can see the date style is Year-Month-Day.If we want to extracct data base on just year alone, we need to split the date column to year, month and day.

# %%
Police_shootings[["year","month","day"]]=Police_shootings["date"].str.split("-",expand = True)
Police_shootings
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
df=Police_shootings
df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
 df.drop(columns=["date"],inplace=True)

# %%
df.head()
# Out:
#    id                name   manner_of_death       armed   age gender  \
# 0   3          Tim Elliot              shot         gun  53.0      M
# 1   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 4   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category  year month day
# ...

# %%
df.shape
# Out:
# (4895, 17)

# %%
df.drop(columns=["body_camera"], inplace=True)

# %%
df.head()
# Out:
#    id                name   manner_of_death       armed   age gender  \
# 0   3          Tim Elliot              shot         gun  53.0      M
# 1   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 4   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee          arms_category  year month day
# 0  Not fleeing                   Guns  2015    01  02
# ...

# %%
df.shape
# Out:
# (4895, 16)

# %%
#convert the year column to datetime using:
#Police_shootings["year"]=pd.to_datetime(Police_shootings["year"])
Police_shootings["year"]=pd.to_datetime(Police_shootings["year"])

# %%
Police_shootings.dtypes
# Out:
# id                                  int64
# name                               object
# manner_of_death                    object
# armed                              object
# age                               float64
# gender                             object
# race                               object
# city                               object
# state                              object
# signs_of_mental_illness              bool
# threat_level                       object
# flee                               object
# arms_category                      object
# year                       datetime64[ns]
# month                              object
# day                                object
# dtype: object

# %%
#if we want to change the position of a feature, we can use the reindex() fuction
df = df.reindex(columns = ["year","name", "manner_of_death","armed","age", "gender","race","city","state","sign_of_mental_illness","threat_level","flee","arms_category"])
print(df)
# Out:
#            year                name   manner_of_death       armed   age  \
# 0    2015-01-01          Tim Elliot              shot         gun  53.0
# 1    2015-01-01    Lewis Lee Lembke              shot         gun  47.0
# 2    2015-01-01  John Paul Quintero  shot and Tasered     unarmed  23.0
# 3    2015-01-01     Matthew Hoffman              shot  toy weapon  32.0
# 4    2015-01-01   Michael Rodriguez              shot    nail gun  39.0
# ...         ...                 ...               ...         ...   ...
# 4890 2020-01-01     Rayshard Brooks              shot       Taser  27.0
# 4891 2020-01-01      Caine Van Pelt              shot         gun  23.0
# 4892 2020-01-01        Hannah Fizer              shot     unarmed  25.0
# 4893 2020-01-01      William Slyter              shot         gun  22.0
# 4894 2020-01-01      Nicholas Hirsh              shot         gun  31.0
#
#      gender      race           city state  sign_of_mental_illness  \
# ...

# %%
Police_shootings = pd.DataFrame(df,columns =["year","name", "manner_of_death","armed","age", "gender","race","city","state","sign_of_mental_illness","threat_level","flee","arms_category"])
Police_shootings
# Out:
#            year                name   manner_of_death       armed   age  \
# 0    2015-01-01          Tim Elliot              shot         gun  53.0
# 1    2015-01-01    Lewis Lee Lembke              shot         gun  47.0
# 2    2015-01-01  John Paul Quintero  shot and Tasered     unarmed  23.0
# 3    2015-01-01     Matthew Hoffman              shot  toy weapon  32.0
# 4    2015-01-01   Michael Rodriguez              shot    nail gun  39.0
# ...         ...                 ...               ...         ...   ...
# 4890 2020-01-01     Rayshard Brooks              shot       Taser  27.0
# 4891 2020-01-01      Caine Van Pelt              shot         gun  23.0
# 4892 2020-01-01        Hannah Fizer              shot     unarmed  25.0
# 4893 2020-01-01      William Slyter              shot         gun  22.0
# 4894 2020-01-01      Nicholas Hirsh              shot         gun  31.0
#
#      gender      race           city state  sign_of_mental_illness  \
# ...

# %%
df = Police_shootings

# %%
#exporting data as csv to my drive by setting index = false
df.to_csv("P_shootings.csv",index = False)

# %%
P_shootings = pd.read_csv(r"C:\Users\barry\Documents\Police_shootings.csv")

# %%
P_shootings.head()
# Out:
#          year                name   manner_of_death       armed   age gender  \
# 0  2015-01-01          Tim Elliot              shot         gun  53.0      M
# 1  2015-01-01    Lewis Lee Lembke              shot         gun  47.0      M
# 2  2015-01-01  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3  2015-01-01     Matthew Hoffman              shot  toy weapon  32.0      M
# 4  2015-01-01   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  sign_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     NaN       attack
# 1     White          Aloha    OR                     NaN       attack
# 2  Hispanic        Wichita    KS                     NaN        other
# 3     White  San Francisco    CA                     NaN       attack
# 4  Hispanic          Evans    CO                     NaN       attack
#
#           flee          arms_category
# 0  Not fleeing                   Guns
# ...

# %% [markdown]
# Now that we're done with data preprocessing, we can now visualise and analyse our data to gain an indepth insight on the circumstance surrounding these shootings and how it an be reduced to barest minimum

# %%
# to check for the year most killings occurred
year_highest_death =P_shootings.year.value_counts()
year_highest_death
# Out:
# 2015-01-01    965
# 2017-01-01    906
# 2016-01-01    904
# 2018-01-01    888
# 2019-01-01    858
# 2020-01-01    374
# Name: year, dtype: int64

# %%
year_highest_death.index
# Out:
# Index(['2015-01-01', '2017-01-01', '2016-01-01', '2018-01-01', '2019-01-01',
#        '2020-01-01'],
#       dtype='object')

# %%
#plotting a bar chart to represent the year with highest death, I'll import packages again
year = ['2015-01-01', '2017-01-01', '2016-01-01', '2018-01-01', '2019-01-01',
       '2020-01-01']
data = P_shootings.year.value_counts()
fig = plt.figure(figsize = (11,6))
plt.bar(year, data, facecolor = "green", ec= "black")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.savefig("Death tool per year.png")

# %%
#to check the with the highest death
gender_with_highest_death = P_shootings.gender.value_counts()
gender_with_highest_death
# Out:
# M    4673
# F     222
# Name: gender, dtype: int64

# %%
gender_with_highest_death.index
# Out:
# Index(['M', 'F'], dtype='object')

# %%
#Using a pie chart to represent this,
plt.title("gender_with_highest_death")
explode= (0,0.1)
plt.pie(gender_with_highest_death, labels=gender_with_highest_death.index,explode=explode, autopct='%0.1f%%', shadow =  True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x26909ebc850>,
# ...
#  [Text(-0.1561969153922113, -1.0888537659492934, 'M'),
#   Text(0.17039663497332158, 1.1878404719446838, 'F')],
#  [Text(-0.08519831748666071, -0.5939202359723418, '95.5%'),
#   Text(0.09939803706777092, 0.6929069419677321, '4.5%')])

# %%
plt.savefig("Gender most killed.png")

# %%
s = plt.figure(figsize = (7,5))
fig = sns.scatterplot(x= "age", y= "race", hue = "gender", data= Police_shootings)

# %%
plt.savefig("race vs gender and age.png")

# %%
#for race with highest victims
race_most_shot = P_shootings.race.value_counts()
race_most_shot
# Out:
# White       2476
# Black       1298
# Hispanic     902
# Asian         93
# Native        78
# Other         48
# Name: race, dtype: int64

# %%
race_most_shot.index
# Out:
# Index(['White', 'Black', 'Hispanic', 'Asian', 'Native', 'Other'], dtype='object')

# %%
#Using a bar chart to represent this,
race= race_most_shot.index
data =  P_shootings.race.value_counts()
fig = plt.figure(figsize = (10,5))
plt.bar(race, data, facecolor = "blue", ec= "black")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.savefig("Race with highest shootings.png")

# %%
#for state where most killings occurred
highest_state = P_shootings.state.value_counts()
highest_state
# Out:
# CA    701
# TX    426
# FL    324
# AZ    222
# CO    168
# GA    161
# OK    151
# NC    148
# OH    146
# WA    126
# TN    125
# MO    124
# LA    102
# IL     99
# PA     95
# AL     95
# NM     93
# VA     92
# IN     91
# NY     90
# WI     88
# KY     87
# NV     85
# SC     80
# MD     77
# OR     76
# AR     73
# MI     71
# MS     61
# MN     60
# NJ     60
# UT     58
# KS     49
# WV     46
# ID     37
# AK     36
# MA     33
# IA     31
# MT     29
# HI     29
# NE     24
# ME     21
# CT     20
# SD     14
# DC     13
# WY     13
# NH     12
# ND     11
# DE     10
# VT      8
# RI      4
# Name: state, dtype: int64

# %%
#for most occurred manner of death
most_frequent_manner_of_death = P_shootings.manner_of_death.value_counts()
most_frequent_manner_of_death
# Out:
# shot                4647
# shot and Tasered     248
# Name: manner_of_death, dtype: int64

# %%
most_frequent_manner_of_death.index
# Out:
# Index(['shot', 'shot and Tasered'], dtype='object')

# %%
#checking the number of victims who fled from the police using the count method
flee = P_shootings.flee.value_counts()
flee
# Out:
# Not fleeing    3073
# Car             820
# Foot            642
# Other           360
# Name: flee, dtype: int64

# %%
#to check the type of arms the victims were found with using the count method
arms_category= P_shootings.arms_category.value_counts()
arms_category
# Out:
# Guns                     2764
# Sharp objects             818
# Unknown                   418
# Unarmed                   348
# Other unusual objects     192
# Blunt instruments         122
# Vehicles                  121
# Multiple                   54
# Piercing objects           29
# Electrical devices         24
# Explosives                  4
# Hand tools                  1
# Name: arms_category, dtype: int64

# %%
sns.histplot(Police_shootings.arms_category)
# Out:
# <AxesSubplot:xlabel='arms_category', ylabel='Count'>

# %%
threat_level= P_shootings.threat_level.value_counts()
threat_level
# Out:
# attack          3160
# other           1528
# undetermined     207
# Name: threat_level, dtype: int64

# %%
sns.histplot(Police_shootings.threat_level)
# Out:
# <AxesSubplot:xlabel='threat_level', ylabel='Count'>

# %%
plt.savefig("Threat level.png")

# %% [markdown]
# This was an assignment done to explore the US police shootings data.
# It is no longer news when we get reports of police shootings; both in our local communities or from global reports. It has become a menace that is proven difficult to put an end to. Ranging from justified shootings to unjust shootings, there is no gainsaying that there is a need to re-educate this entity who are meant to protect lives and properties of civilians.
# Police violence is a leading cause of death for young men in the United States. Risk of being killed by police peaks between the ages of 20 and 30 years for men and women and for all racial and ethnic groups.
# In Nigeria today, it has become a question of “who can we trust between a thief and a police officer?” there has been so many reports of police shooting harmless civilians. Unlike the US where arms are legal, in Nigeria it is not. So, it can be said that 99% of police shootings in Nigeria is unjust. It got so bad that the youths had to take to the streets to protest police brutality after a video of a harmless boy shot in day light made rounds on the internet. The Nigerian police responded to the protesters by shooting live rounds at harmless protesters, arresting protesters unjustly and even kidnapping protesters.
# The data is a record of the US police shootings that happened from 2015–2020. It had details of the victims’ gender, race, manner of death, arms category, sign of mental illness, whether they tried to flee, whether they attempted to attack the police or not and the date of occurrence.
# after exploring and visualizing the data across 4895 rows, below are my observations.
# Visualizing the data across the years of occurrence, using different visualization tools/methods, I observed the year with the highest shootings to be 2015 with a count of 965 victims followed by 2017 having a count of 906 victims.
# Across race, the race with most victims is white with a count of 2476 victims and followed by it is the Black race with a count of 1298 victims. The gender with more victims is the male. There were more male victims than women with a count of 4673 out of 4895 victims of police shootings leaving the count of female victims as 222. It was also observed that 348 unarmed people were shot, and 2764 victims had a gun on them. some of the victims had a face-off with the police which might have led to the shootings because the number of victims who got shot because they attacked the police were 3160 which is way higher than the unharmed victims.
